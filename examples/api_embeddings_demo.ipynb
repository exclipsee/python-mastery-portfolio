# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "archived",
#    "metadata": {},
#    "source": [
#     "This notebook has been moved to archive/examples/api_embeddings_demo.ipynb to simplify the repository.\n",
#     "To view the original content open: archive/examples/api_embeddings_demo.ipynb"
#    ]
#   }
#  ],
#  "metadata": {
#   "language_info": {
#    "name": "python"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
